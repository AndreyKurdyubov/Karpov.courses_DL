# %%
# Настройка окружения
# !pip install datasets==3.2.0 open_clip_torch==2.29.0 nltk==3.9.1

# %%
import math
import time
from typing import Tuple, List, Dict

import matplotlib.pyplot as plt
import nltk
import torch
from datasets import load_dataset
from nltk.corpus import wordnet
from open_clip import tokenizer
from PIL import Image

import open_clip
from sklearn.metrics import accuracy_score
from sklearn.metrics import top_k_accuracy_score

# %% [markdown]
# # > Классификация. CLIP

# %% [markdown]
# ## Описание задачи

# %% [markdown]
# В этом задании мы будем решать задачу классификации изображений, используя архитектуру CLIP (Contrastive Language–Image Pre-training). В качестве примера мы воспользуемся уже знакомым нам набором данных Tiny ImageNet. Однако на этот раз мы не будем обучать модель с нуля. Вместо этого мы применим Zero Shot —  классификацию, используя предобученную модель CLIP.

# %% [markdown]
# ## План
# 1. **Подготовка модели**: загрузим предобученную модель CLIP из библиотеки open_clip_torch.
# 2. **Подготовка данных**: подготовим изображения и текстовые метки (классы) для инференса модели.
# 3. **Подготовка пайплайна**: создадим пайплайн для инференса и оценки качества модели на заданном наборе данных.
# 4. **Сравнение моделей**: сравним между собой предобученные модели.

# %% [markdown]
# # > Подготовка модели

# %% [markdown]
# Как уже обсуждали ранее на практических занятиях, реализацию CLIP мы возьмём из репозитория [open_clip](https://github.com/mlfoundations/open_clip).
#
# Ещё раз посмотрим список доступных моделей и для примера возьмём первую из них.

# %%
pretrain_models = open_clip.list_pretrained()
print(pretrain_models)

# %% [markdown]
# Реализуем функцию `load_model`, которая инициализирует и подготавливает модель для инференса. Для примера будем рассматривать модель ('RN50', 'openai').

# %%
def load_model(model_name, pretrained) -> open_clip.model.CLIP:
    """
    Загружает и подготавливает модель CLIP для использования.

    :param model_name: Имя модели, которую необходимо загрузить.
    :param pretrained: Датасет, на котором обучалась модель.

    :return model, preprocess: Кортеж, содержащий загруженную модель CLIP и объект обработки изображений.
    """
    model, _, preprocess = open_clip.create_model_and_transforms(model_name, pretrained=pretrained)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    return model, preprocess

model, preprocess = load_model(model_name='RN50', pretrained='openai')

# %% [markdown]
# Внесите в LMS ответ на следующий вопрос:
#
# Задание 1. Сколько уникальных архитектур моделей доступно в `open_clip`?

# %%
num_models = set()
for model_name, data in pretrain_models:
    num_models.add(model_name)

print(num_models)
print(len(num_models))

# %% [markdown]
# # > Подготовка данных

# %% [markdown]
# Скачаем напрямую с `huggingface` датасет `tiny-imagenet`. Так как мы не планируем обучать модель, а хотим оценить её качество, то возьмём только валидационную часть датасета.

# %%
dataset = load_dataset("zh-plus/tiny-imagenet", split="valid")

# %% [markdown]
# Давайте ещё раз взглянем на датасет и разберёмся, в каком формате представлены наши данные и как их можно извлекать.

# %%
fig, axes = plt.subplots(1, 10, figsize=(15, 3))
for plot_index, data_index in enumerate(range(0, 1000, 100)):
  image = dataset["image"][data_index]
  label = dataset["label"][data_index]
  axes[plot_index].imshow(image)
  axes[plot_index].set_title(f"Class: {label}")
  axes[plot_index].axis('off')

# %% [markdown]
# Изучите датасет и внесите в LMS ответы на следующие вопросы:
#
# - **Задание 2.1.** Cколько всего примеров в датасете?
# - **Задание 2.2.** Cколько различных классов в датасете?
# - **Задание 2.3.** Cколько примеров каждого класса в датасете?

# %%
# Задание 2.1. Cколько всего примеров в датасете?
images = dataset["image"]
labels = dataset['label']
len(dataset), type(images[0])

# %%
# Задание 2.2.** Cколько различных классов в датасете?
from collections import Counter
Counter(labels)

# %% [markdown]
# ## Подготовка текстовых описаний классов
#
# Мы посмотрели, как выглядят исходные данные, теперь научимся их подготавливать для работы с моделями CLIP. Как вы могли догадаться, номера классов не подойдут нам для описания изображений. Нам нужно преобразовать их в читаемый текст.
# Посмотрим, есть ли в нашем датасете текстовое описание классов.

# %%
names = dataset.features['label'].names
print(names)

# %% [markdown]
# В таком виде имена классов тоже не подойдут, поскольку для использования модели CLIP нам нужно задать текстовый запрос, с которым модель будет сравнивать изображения.
#
# На самом деле эти странные имена — `'n01443537'` — являются кодировкой классов из датасета `ImageNet` в «базе данных» `WordNet` и их можно сопоставить с текстовым названием класса. Для этого можно воспользоваться библиотекой `nltk`, которая умеет работать с такой кодировкой.

# %%
nltk.download('wordnet')

# %% [markdown]
# Не вдаваясь в подробности: чтобы получить имя класса, можно воспользоваться следующим кодом:

# %%
name = names[1]
synset = wordnet.synset_from_pos_and_offset('n', int(name[1:]))
text = synset.lemma_names()[0]

print(f'{name} -> {text}')

# %% [markdown]
# Давайте для удобства работы с датасетом создадим функцию, которая будет сопоставлять индекс класса (из `dataset["label"]`) с его названием.
#
# Индексы классов совпадают с их индексом в списке `dataset.features['label'].names`.
#
# **Задание 3.** Реализуйте функцию `label_index_to_name`, которая будет сопоставлять индексы классов с их названием. На вход функция принимает индекс класса, на выход выдаёт его имя. Если передан некорректный индекс, необходимо вернуть ошибку `ValueError` c описанием `f"Invalid index: {index}"`.

# %%
def label_index_to_name(index: int, names) -> str:
    """
    Преобразует индекс метки в человекочитаемое имя, используя заданный набор имён.
    
    :param index: Целочисленный индекс метки из списка имён.
    :param names: Список имён в кодировке WordNet, соответствующих меткам в наборе данных.
    :return: Человекочитаемое имя класса, соответствующее заданному индексу метки.
    
    :raises ValueError: Если переданный индекс не является целым числом или находится вне диапазона допустимых значений.
    """
    if (type(index) != int) or not (0 <= index < 200):
        raise ValueError(f"Invalid index: {index}")

    name = names[index]
    synset = wordnet.synset_from_pos_and_offset('n', int(name[1:]))
    text = synset.lemma_names()[0]    
    return text

# %% [markdown]
# Пример использования:

# %%
image_index = 1000
labels = dataset["label"]
label_index = labels[image_index]
print(label_index)

names = dataset.features['label'].names
print(names)

name = label_index_to_name(index=label_index, names=names)
print(name)

# %% [markdown]
# ## Создание текстовых описаний

# %% [markdown]
# Создадим список человекочитаемых имён классов и будем работать уже с ним.

# %%
labels_names = [label_index_to_name(i, names) for i in range(len(names))]
print(labels_names)

# %% [markdown]
# **Задание 4.** Теперь, когда у вас есть список классов, реализуйте функцию create_prompts, которая будет формировать для наших классов текстовое описание `(prompt)`. На вход она будет принимать список имён классов (человекочитаемых) и шаблон, в который они будут подставлены для формирования текстового описания.

# %%
def create_prompts(labels_names: list[str], template: str) -> list[str]:
    """
    Создаёт список текстовых подсказок (prompts) на основе заданного шаблона и списка имён меток.
    
    :param labels_names: Список строк, содержащий имена меток, которые будут подставлены в шаблон.
    :param template: Строка-шаблон, в которую подставляются имена меток из списка; должна содержать один маркер подстановки "{}".
    :return: Список строк, где каждая строка представляет собой шаблон с подставленным именем метки.
    """
    # Ваш код здесь
    prompts = [template.replace("{}", name) for name in labels_names]
    return prompts

# %% [markdown]
# Создадим список промптов для нашего датасета.

# %%
template = "a photo of {}"
template.format("sdfsdf")

# %%
template = "a photo of {}"
prompts = create_prompts(labels_names, template)
print(prompts)

# %% [markdown]
# # > Подготовка пайплайна
# ### Энкодинг текстов
#
# Теперь, когда у нас есть читаемые описания классов, нам нужно извлечь из них эмбеддинги с помощью энкодера модели CLIP. Напишите функцию для преобразования наших запросов в эмбеддинг. Для этого необходимо токенизировать текст при помощи `tokenizer`, прогнать его через энкодер модели.
#
# **Задание 5.** Реализуйте на основе материалов практического занятия функцию `get_text_embeddings`.

# %%
def get_text_embeddings(model, prompt: list[str]) -> torch.Tensor:
    """
    Получает текстовые эмбеддинги для списка запросов.

    :param model: Модель для инференса.
    :param prompt: Список строк, каждая из которых представляет собой текстовый запрос.
    :return: Тензор PyTorch, содержащий нормализованные эмбеддинги текстов.
    """
    # получим токены
    text_tokens = tokenizer.tokenize(prompt)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # текстовых описаний мало, для них мы один раз получим эмбеддинги
    with torch.no_grad():
        text_embeddings = model.encode_text(text_tokens.to(device)).float()
    
    # обязательно их нормализуем, чтобы вектор оказался на едииничной сфере
    text_embeddings /= text_embeddings.norm(dim=-1, keepdim=True)
    return text_embeddings

# %% [markdown]
# Пример использования:

# %%
prompts = labels_names

text_embeddings = get_text_embeddings(model, prompts)
print(text_embeddings.shape)

# %% [markdown]
# ## Энкодинг изображений

# %% [markdown]
# Теперь нам необходимо подготовить изображения для инференса модели. Для этого воспользуемся функцией `preprocess`, которую мы получили при инициализации модели, и получим эмбеддинг при помощи энкодера.
#
# **Задание 6.** Реализуйте функцию `get_image_embedding`.

# %%
def get_image_embedding(model, image: torch.Tensor) -> torch.Tensor:
    """
    Получает эмбеддинг изображения с использованием предварительно обученной модели.
    
    :param model: Модель для инференса.
    :param image: Тензор PyTorch, представляющий изображение, для которого необходимо получить эмбеддинг.
    :return: Тензор PyTorch, содержащий эмбеддинг изображения.
    """
    # Ваш код здесь
    with torch.no_grad():
        image_embedding = model.encode_image(image)
    
    # обязательно нормализуем
    # image_embedding /= image_embedding.norm(dim=-1, keepdim=True)
    return image_embedding

# %% [markdown]
# Пример использования:

# %%
EXAMPLE_IMAGE_INDEX = 1
image = dataset["image"][EXAMPLE_IMAGE_INDEX]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

img_tensor = preprocess(image).unsqueeze(0).float().to(device)
print(img_tensor.shape)

image_embedding = get_image_embedding(model, img_tensor)
print(image_embedding.shape, sum(image_embedding[0]**2))

# %% [markdown]
# ### Инференс модели
# **Задание 7.** На предыдущих шагах мы получили эмбеддинги для текстов и изображения. Реализуйте функцию `get_probs`, которая на вход получает эмбеддинги текстов для каждого класса и эмбеддинг изображения. Функция должна возвращать вероятности принадлежности изображения к каждому из классов. Вероятности должны быть нормированы так, чтобы их сумма равнялась 1.
#
# *В качестве множителя, на который будет помножено матричное перемножение векторов, возьмите 100. Это применяют, чтобы увеличить разницу в значениях, что делает softmax-распределение более «острым», то есть наибольший элемент будет иметь более высокую «уверенность».*

# %%
def get_probs(image_embedding, text_embeddings):
  """
  Вычисляет вероятности соответствия изображения текстовым подсказкам на основе эмбеддингов.

  :param image_embedding: Тензор PyTorch, представляющий эмбеддинг изображения.
  :param text_embeddings: Тензор PyTorch, содержащий эмбеддинги текстовых подсказок.
  :return: Тензор PyTorch, представляющий вероятности соответствия между изображением и текстовыми подсказками.
  """
  probs = (100 * image_embedding @ text_embeddings.T).softmax(dim=-1)
  return probs


text_embeddings = get_text_embeddings(model, prompts[1])
image_embedding = get_image_embedding(model, img_tensor)
probs = get_probs(image_embedding, text_embeddings)
print(probs)

# %% [markdown]
# ### Оценка качества классификации
#
# **Задание 8.** Для оценки качества классификации реализуйте topK_accuracy.

# %%
from sklearn.metrics import top_k_accuracy_score

def calculate_topk_accuracy(probs, gts, k=1):
    """
    Вычисляет top-k accuracy.

    :param probs: Тензор вероятностей размера (num_samples, num_classes).
    :param gts: Истинные метки классов.
    :param k: Параметр top-k, по умолчанию равен 1.
    :return: Точность классификации top-k.
    """
    # Ваш код здесь
    labels = list(range(probs.shape[1]))
    accuracy = top_k_accuracy_score(gts, probs, k=k, labels=labels)
    return accuracy

# без sklearn topk
def calculate_topk_accuracy_2(probs, gts, k=1):
    """
    Вычисляет top-k accuracy.

    :param probs: Тензор вероятностей размера (num_samples, num_classes).
    :param gts: Истинные метки классов.
    :param k: Параметр top-k, по умолчанию равен 1.
    :return: Точность классификации top-k.
    """
    # Получаем индексы k наибольших вероятностей для каждого образца
    # shape: (num_samples, k)
    topk_indices = torch.topk(probs, k, dim=-1).indices

    if not torch.is_tensor(gts):
        gts = torch.tensor(gts)
        
    # Расширяем размерность gts для корректного сравнения
    # Превращаем gts из shape (num_samples,) в (num_samples, 1)
    gts_expanded = gts.unsqueeze(-1)
    
    # Сравниваем с истинными метками используя метод eq()
    # Если хотя бы один из top-k индексов совпадает с истинной меткой, то ответ верный
    correct = topk_indices.eq(gts_expanded).any(dim=-1)
    
    # Считаем долю правильных ответов
    accuracy = correct.float().mean().item()
    
    return accuracy

# %% [markdown]
# Пример использования:

# %%
probs = torch.tensor([
        [0.2, 0.5, 0.3],
        [0.1, 0.4, 0.5],
        [0.7, 0.2, 0.1]
])
gts = [1, 1, 1]
k = 1
accuracy = calculate_topk_accuracy_2(probs, gts, k)

print(accuracy)

# %% [markdown]
# # > Сравнение моделей
# Мы реализовали весь необходимый функционал для инференса модели и оценки качества классификации. Теперь нам предстоит протестировать некоторые из предобученных моделей и сравнить их между собой.
#
# Хорошей практикой в данном случае будет объединить наши функции в некий пайплайн, который мы будем запускать.
#
# Ниже я предложу один из вариантов того, как это может выглядеть. Как именно он будет реализован в данном случае, не важно, главное — чтобы для каждой модели вы могли получить значения Top-1/5/10 Accuracy на нашем датасете.

# %%
# !pip install datasets==3.2.0 open_clip_torch==2.29.0 nltk==3.9.1
# Out:
# Collecting datasets==3.2.0
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Collecting open_clip_torch==2.29.0
#   Downloading open_clip_torch-2.29.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (3.24.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (23.0.1)
# Collecting dill<0.3.9,>=0.3.0 (from datasets==3.2.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (0.70.16)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets==3.2.0)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (3.13.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0) (6.0.3)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch==2.29.0) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open_clip_torch==2.29.0) (0.25.0+cu128)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open_clip_torch==2.29.0) (2025.11.3)
# Collecting ftfy (from open_clip_torch==2.29.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open_clip_torch==2.29.0) (0.7.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from open_clip_torch==2.29.0) (1.0.25)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1) (1.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0) (1.22.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->datasets==3.2.0) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->datasets==3.2.0) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->datasets==3.2.0) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->datasets==3.2.0) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->datasets==3.2.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.2.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.2.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.2.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.2.0) (2026.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->open_clip_torch==2.29.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.9.0->open_clip_torch==2.29.0) (1.3.5)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open_clip_torch==2.29.0) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.2.0) (2025.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->open_clip_torch==2.29.0) (11.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets==3.2.0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets==3.2.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets==3.2.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.2.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9.0->open_clip_torch==2.29.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9.0->open_clip_torch==2.29.0) (3.0.3)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.23.0->datasets==3.2.0) (0.24.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.23.0->datasets==3.2.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.23.0->datasets==3.2.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.23.0->datasets==3.2.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.23.0->datasets==3.2.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.23.0->datasets==3.2.0) (0.1.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 10.3 MB/s eta 0:00:0000:01
# Downloading open_clip_torch-2.29.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 38.2 MB/s eta 0:00:0000:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.7 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: ftfy, fsspec, dill, datasets, open_clip_torch
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2026.2.0
#     Uninstalling fsspec-2026.2.0:
#       Successfully uninstalled fsspec-2026.2.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.4.1
#     Uninstalling dill-0.4.1:
#       Successfully uninstalled dill-0.4.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.8.3
#     Uninstalling datasets-4.8.3:
#       Successfully uninstalled datasets-4.8.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# s3fs 2026.2.0 requires fsspec==2026.2.0, but you have fsspec 2024.9.0 which is incompatible.
# tpot 1.1.0 requires dill>=0.3.9, but you have dill 0.3.8 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 ftfy-6.3.1 open_clip_torch-2.29.0

# %%
# !nvidia-smi
# Out:
# Sat May 23 03:53:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import math
import time
from typing import Tuple, List, Dict

import matplotlib.pyplot as plt
import nltk
import torch
from datasets import load_dataset
from nltk.corpus import wordnet
from open_clip import tokenizer
from PIL import Image

import open_clip
from sklearn.metrics import accuracy_score
from sklearn.metrics import top_k_accuracy_score
import tqdm

dataset = load_dataset("zh-plus/tiny-imagenet", split="valid")
nltk.download('wordnet')

fig, axes = plt.subplots(1, 10, figsize=(15, 3))
for plot_index, data_index in enumerate(range(0, 1000, 100)):
    image = dataset["image"][data_index]
    label = dataset["label"][data_index]
    axes[plot_index].imshow(image)
    axes[plot_index].set_title(f"Class: {label}")
    axes[plot_index].axis('off')
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# dataset_infos.json: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001-1359597a978bc4(…):   0%|          | 0.00/146M [00:00<?, ?B/s]
# data/valid-00000-of-00001-70d52db3c749a9(…):   0%|          | 0.00/14.6M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def label_index_to_name(index: int, names) -> str:
    """
    Преобразует индекс метки в человекочитаемое имя, используя заданный набор имён.
    
    :param index: Целочисленный индекс метки из списка имён.
    :param names: Список имён в кодировке WordNet, соответствующих меткам в наборе данных.
    :return: Человекочитаемое имя класса, соответствующее заданному индексу метки.
    
    :raises ValueError: Если переданный индекс не является целым числом или находится вне диапазона допустимых значений.
    """
    if (type(index) != int) or not (0 <= index < 200):
        raise ValueError(f"Invalid index: {index}")

    name = names[index]
    synset = wordnet.synset_from_pos_and_offset('n', int(name[1:]))
    text = synset.lemma_names()[0]    
    return text
    

class CLIPClassifier:
    def __init__(self, model_name, pretrained, device):
        """Инициализация предобученной модели из open_clip"""
        self.device = device
        self.model, _, self.preprocess = open_clip.create_model_and_transforms(
            model_name, pretrained=pretrained)
        self.model.to(device)
        self.model.eval()

    def create_prompts(self, labels_names: List[str], template: str) -> List[str]:
        """Создание запросов в модель на основе имён классов и шаблона"""
        prompts = [template.replace("{}", name) for name in labels_names]
        return prompts

    def get_text_embeddings(self, prompts: List[str]) -> torch.Tensor:
        """Получение эмбеддингов для запросов в модель"""
        text_tokens = tokenizer.tokenize(prompts)
        
        with torch.no_grad():
            text_embeddings = self.model.encode_text(
                text_tokens.to(self.device)).float()
    
        text_embeddings /= text_embeddings.norm(dim=-1, keepdim=True)
        return text_embeddings

    def get_image_embedding(self, img_tensor: torch.Tensor) -> torch.Tensor:
        """Получение эмбеддинга для изображения"""
        with torch.no_grad():
            image_embedding = self.model.encode_image(img_tensor)
        return image_embedding
  
    def classify(self, images, class_labels, template="a photo of a {}", batch_size=64):
        """Классификация изображений на основе эмбеддингов текста и изображений"""

        prompts = self.create_prompts(class_labels, template)
        text_features = self.get_text_embeddings(prompts)
    
        all_probs = []
    
        for i in tqdm.trange(0, len(images), batch_size):
            batch_images = images[i:i + batch_size]
    
            img_tensors = torch.stack([
                self.preprocess(img)for img in batch_images
            ]).to(self.device).float()
    
            image_features = self.get_image_embedding(img_tensors)
            image_features /= image_features.norm(dim=-1, keepdim=True)
    
            probs = (100.0 * image_features @ text_features.T).softmax(dim=-1)
    
            all_probs.append(probs.cpu())
    
            # очистка памяти
            del img_tensors
            del image_features
            del probs
            torch.cuda.empty_cache()
    
        probs = torch.cat(all_probs, dim=0)
        return probs
        

    def calculate_topk_accuracy(self, probs, gts, k=1):
        """
        Вычисляет top-k accuracy.

        :param probs: Тензор вероятностей размера (num_samples, num_classes).
        :param gts: Истинные метки классов.
        :param k: Параметр top-k, по умолчанию равен 1.
        :return: Точность классификации top-k.
        """
        labels = list(range(probs.shape[1]))
        accuracy = top_k_accuracy_score(gts, probs, k=k, labels=labels)
        return accuracy

# Пример использования
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
templates = ['a photo of {}']
names = dataset.features['label'].names
labels_names = [label_index_to_name(i, names) for i in range(len(names))]

for name, pretrain in [('RN50', 'openai'), ('RN50', 'yfcc15m'), ('RN50', 'cc12m')]:
    print(f"Model: {name}")
    print(f"Pretrain: {pretrain}")
    for template in templates:
        print(f"Template: {template}")
        classifier = CLIPClassifier(name, pretrain, device)
        images = dataset["image"]            
        probs = classifier.classify(images, labels_names, template)
        
        gts = dataset["label"]
                
        top1_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=1)
        print(f"Top-1 Accuracy: {top1_accuracy:.2f}")
        
        top5_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=5)
        print(f"Top-5 Accuracy: {top5_accuracy:.2f}")
        
        top10_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=10)
        print(f"Top-10 Accuracy: {top10_accuracy:.2f}")
# Out:
# Model: RN50
# Pretrain: openai
# Template: a photo of {}
# 100%|██████████| 157/157 [00:59<00:00,  2.62it/s]
# Top-1 Accuracy: 0.29
# Top-5 Accuracy: 0.55
# Top-10 Accuracy: 0.67
# Model: RN50
# Pretrain: yfcc15m
# Template: a photo of {}
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:372: UserWarning: These pretrained weights were trained with QuickGELU activation but the model config does not have that enabled. Consider using a model config with a "-quickgelu" suffix or enable with a flag.
#   warnings.warn(
# 100%|██████████| 157/157 [00:58<00:00,  2.68it/s]
# Top-1 Accuracy: 0.08
# Top-5 Accuracy: 0.24
# Top-10 Accuracy: 0.35
# Model: RN50
# Pretrain: cc12m
# Template: a photo of {}
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:372: UserWarning: These pretrained weights were trained with QuickGELU activation but the model config does not have that enabled. Consider using a model config with a "-quickgelu" suffix or enable with a flag.
#   warnings.warn(
# 100%|██████████| 157/157 [00:58<00:00,  2.67it/s]
# Top-1 Accuracy: 0.12
# Top-5 Accuracy: 0.30
# Top-10 Accuracy: 0.40

# %% [markdown]
# ## 2026.05.23 результаты
# **Задание 9.1.** Модель, предобученная на каком из датасетов показывает лучшее значение Top-1 Accuracy?
# Шаблон для запросов: "a photo of {}".
#
# #### С нормировкой изображений
#
# Model: RN50
# Pretrain: openai
# Top-1 Accuracy: 0.29
# Top-5 Accuracy: 0.55
# Top-10 Accuracy: 0.67
#
# Model: RN50
# Pretrain: yfcc15m
# Top-1 Accuracy: 0.08
# Top-5 Accuracy: 0.24
# Top-10 Accuracy: 0.35
#
# Model: RN50
# Pretrain: cc12m
# Top-1 Accuracy: 0.12
# Top-5 Accuracy: 0.30
# Top-10 Accuracy: 0.40
#
# #### Без нормировки изображений
# Model: RN50
# Pretrain: openai
# Top-1 Accuracy: 0.29
# Top-5 Accuracy: 0.55
# Top-10 Accuracy: 0.67
#
# Model: RN50
# Pretrain: yfcc15m
# Top-1 Accuracy: 0.08
# Top-5 Accuracy: 0.23
# Top-10 Accuracy: 0.32
#
# Model: RN50
# Pretrain: cc12m
# Top-1 Accuracy: 0.12
# Top-5 Accuracy: 0.30
# Top-10 Accuracy: 0.40

# %%
templates = ['a photo of {}']
pretrain_models = open_clip.list_pretrained()
for name, pretrain in [('RN50', 'openai'), ('RN50', 'yfcc15m'), ('RN50', 'cc12m')]:
  print(f"Model: {name}")
  print(f"Pretrain: {pretrain}")
  for template in templates:
    print(f"Template: {template}")
    classifier = CLIPClassifier(name, pretrain)

    images = dataset["image"]

    probs = classifier.classify(images, labels_names, template)
    gts = dataset["label"]

    top1_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=1)
    print(f"Top-1 Accuracy: {top1_accuracy:.2f}")

    top5_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=5)
    print(f"Top-5 Accuracy: {top5_accuracy:.2f}")

    top10_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=10)
    print(f"Top-10 Accuracy: {top10_accuracy:.2f}")
    print()

# %% [markdown]
# **Задание 9.2.** Какой из шаблонов позволяет добиться наилучшего качества Top-5 Accuracy для модели ViT-B-32, laion2b_s34b_b79k?

# %%
templates = ['{}', 'a photo of {}', 'photo of {} from ImageNet dataset', 'a photo showing a {}']
pretrain_models = open_clip.list_pretrained()

name = 'ViT-B-32'
pretrain = 'laion2b_s34b_b79k'
print(f"Model: {name}")
print(f"Pretrain: {pretrain}")
for template in templates:
    print(f"Template: {template}")
    classifier = CLIPClassifier(name, pretrain, device)
    
    images = dataset["image"]
    
    probs = classifier.classify(images, labels_names, template)
    gts = dataset["label"]
    
    top1_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=1)
    print(f"Top-1 Accuracy: {top1_accuracy:.2f}")
    
    top5_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=5)
    print(f"Top-5 Accuracy: {top5_accuracy:.2f}")
    
    top10_accuracy = classifier.calculate_topk_accuracy(probs, gts, k=10)
    print(f"Top-10 Accuracy: {top10_accuracy:.2f}")
    print()
# Out:
# Model: ViT-B-32
# Pretrain: laion2b_s34b_b79k
# Template: {}
# 100%|██████████| 157/157 [00:48<00:00,  3.26it/s]
# Top-1 Accuracy: 0.63
# Top-5 Accuracy: 0.82
# Top-10 Accuracy: 0.87
#
# Template: a photo of {}
# 100%|██████████| 157/157 [00:45<00:00,  3.44it/s]
# Top-1 Accuracy: 0.65
# Top-5 Accuracy: 0.85
# Top-10 Accuracy: 0.90
#
# Template: photo of {} from ImageNet dataset
# 100%|██████████| 157/157 [00:47<00:00,  3.29it/s]
# Top-1 Accuracy: 0.65
# Top-5 Accuracy: 0.85
# Top-10 Accuracy: 0.90
#
# Template: a photo showing a {}
# 100%|██████████| 157/157 [00:46<00:00,  3.36it/s]
# Top-1 Accuracy: 0.67
# Top-5 Accuracy: 0.87
# Top-10 Accuracy: 0.92

# %% [markdown]
# ### Результаты с нормировкой изображений
# Model: ViT-B-32
# Pretrain: laion2b_s34b_b79k
# Template: {}
# Top-1 Accuracy: 0.63
# Top-5 Accuracy: 0.82
# Top-10 Accuracy: 0.87
#
# Template: a photo of {}
# Top-1 Accuracy: 0.65
# Top-5 Accuracy: 0.85
# Top-10 Accuracy: 0.90
#
# Template: photo of {} from ImageNet dataset
# Top-1 Accuracy: 0.65
# Top-5 Accuracy: 0.85
# Top-10 Accuracy: 0.90
#
# Template: a photo showing a {}
# Top-1 Accuracy: 0.67
# Top-5 Accuracy: 0.87
# Top-10 Accuracy: 0.92
#
# ### Результаты без нормировки изображений
# Model: ViT-B-32
# Pretrain: laion2b_s34b_b79k
# Template: {}
# Top-1 Accuracy: 0.63
# Top-5 Accuracy: 0.82
# Top-10 Accuracy: 0.87
#
# Template: a photo of {}
# Top-1 Accuracy: 0.65
# Top-5 Accuracy: 0.85
# Top-10 Accuracy: 0.90
#
# Template: photo of {} from ImageNet dataset
# Top-1 Accuracy: 0.65
# Top-5 Accuracy: 0.85
# Top-10 Accuracy: 0.90
#
# Template: a photo showing a {}
# Top-1 Accuracy: 0.67
# Top-5 Accuracy: 0.87
# Top-10 Accuracy: 0.92
